# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tqdm
import gc
# import sys
# import warnings
# warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Preparation

# %% [markdown]
# As dataset is quite large , we will be solving the problem by breaking down dataset into Chunks and Merging the results afterwards.

# %%
#reading csv files of dataset 
date = pd.read_csv('/Users/maguoyi/Downloads/bosch-production-line-performance/train_date.csv.zip', nrows=10000, low_memory=False)
numeric = pd.read_csv('/Users/maguoyi/Downloads/bosch-production-line-performance/train_numeric.csv.zip', nrows=10000, low_memory=False)
category = pd.read_csv('/Users/maguoyi/Downloads/bosch-production-line-performance/train_categorical.csv.zip', nrows=10000, low_memory=False)

# %%
date
# Out:
#          Id  L0_S0_D1  L0_S0_D3  L0_S0_D5  L0_S0_D7  L0_S0_D9  L0_S0_D11  \
# 0         4     82.24     82.24     82.24     82.24     82.24      82.24
# 1         6       NaN       NaN       NaN       NaN       NaN        NaN
# 2         7   1618.70   1618.70   1618.70   1618.70   1618.70    1618.70
# 3         9   1149.20   1149.20   1149.20   1149.20   1149.20    1149.20
# 4        11    602.64    602.64    602.64    602.64    602.64     602.64
# ...     ...       ...       ...       ...       ...       ...        ...
# 9995  19912       NaN       NaN       NaN       NaN       NaN        NaN
# 9996  19915    904.17    904.17    904.17    904.17    904.17     904.17
# 9997  19917    640.60    640.60    640.60    640.60    640.60     640.60
# 9998  19921       NaN       NaN       NaN       NaN       NaN        NaN
# 9999  19923   1379.75   1379.75   1379.75   1379.75   1379.75    1379.75
#
#       L0_S0_D13  L0_S0_D15  L0_S0_D17  ...  L3_S50_D4246  L3_S50_D4248  \
# 0         82.24      82.24      82.24  ...           NaN           NaN
# 1           NaN        NaN        NaN  ...           NaN           NaN
# 2       1618.70    1618.70    1618.70  ...           NaN           NaN
# 3       1149.20    1149.20    1149.20  ...           NaN           NaN
# 4        602.64     602.64     602.64  ...           NaN           NaN
# ...         ...        ...        ...  ...           ...           ...
# 9995        NaN        NaN        NaN  ...           NaN           NaN
# 9996     904.17     904.17     904.17  ...           NaN           NaN
# 9997     640.60     640.60     640.60  ...           NaN           NaN
# 9998        NaN        NaN        NaN  ...           NaN           NaN
# 9999    1379.75    1379.75    1379.75  ...           NaN           NaN
#
#       L3_S50_D4250  L3_S50_D4252  L3_S50_D4254  L3_S51_D4255  L3_S51_D4257  \
# 0              NaN           NaN           NaN           NaN           NaN
# 1              NaN           NaN           NaN           NaN           NaN
# 2              NaN           NaN           NaN           NaN           NaN
# 3              NaN           NaN           NaN           NaN           NaN
# 4              NaN           NaN           NaN           NaN           NaN
# ...            ...           ...           ...           ...           ...
# 9995           NaN           NaN           NaN           NaN           NaN
# 9996           NaN           NaN           NaN           NaN           NaN
# 9997           NaN           NaN           NaN           NaN           NaN
# 9998           NaN           NaN           NaN           NaN           NaN
# 9999           NaN           NaN           NaN       1380.59       1380.59
#
#       L3_S51_D4259  L3_S51_D4261  L3_S51_D4263
# 0              NaN           NaN           NaN
# 1              NaN           NaN           NaN
# 2              NaN           NaN           NaN
# 3              NaN           NaN           NaN
# 4              NaN           NaN           NaN
# ...            ...           ...           ...
# 9995           NaN           NaN           NaN
# 9996           NaN           NaN           NaN
# 9997           NaN           NaN           NaN
# 9998           NaN           NaN           NaN
# 9999       1380.59       1380.59       1380.59
#
# [10000 rows x 1157 columns]

# %% [markdown]
# The data represents measurements of parts as they move through Bosch's production lines. Each part has a unique Id. The goal is to predict which parts will fail quality control (represented by a 'Response' = 1).
#
# The dataset contains an extremely large number of anonymized features. Features are named according to a convention that tells you the production line, the station on the line, and a feature number. E.g. L3_S36_F3939 is a feature measured on line 3, station 36, and is feature number 3939.
#
# On account of the large size of the dataset, we have separated the files by the type of feature they contain: numerical, categorical, and finally, a file with date features. The date features provide a timestamp for when each measurement was taken. Each date column ends in a number that corresponds to the previous feature number. E.g. the value of L0_S0_D1 is the time at which L0_S0_F0 was taken.

# %%
numeric
# Out:
#          Id  L0_S0_F0  L0_S0_F2  L0_S0_F4  L0_S0_F6  L0_S0_F8  L0_S0_F10  \
# 0         4     0.030    -0.034    -0.197    -0.179     0.118      0.116
# 1         6       NaN       NaN       NaN       NaN       NaN        NaN
# 2         7     0.088     0.086     0.003    -0.052     0.161      0.025
# 3         9    -0.036    -0.064     0.294     0.330     0.074      0.161
# 4        11    -0.055    -0.086     0.294     0.330     0.118      0.025
# ...     ...       ...       ...       ...       ...       ...        ...
# 9995  19912       NaN       NaN       NaN       NaN       NaN        NaN
# 9996  19915    -0.147    -0.168    -0.033    -0.016     0.074      0.161
# 9997  19917    -0.095     0.004     0.330     0.312    -0.143     -0.339
# 9998  19921       NaN       NaN       NaN       NaN       NaN        NaN
# 9999  19923    -0.003    -0.019    -0.015    -0.016     0.118      0.161
#
#       L0_S0_F12  L0_S0_F14  L0_S0_F16  ...  L3_S50_F4245  L3_S50_F4247  \
# 0        -0.015     -0.032      0.020  ...           NaN           NaN
# 1           NaN        NaN        NaN  ...           NaN           NaN
# 2        -0.015     -0.072     -0.225  ...           NaN           NaN
# 3         0.022      0.128     -0.026  ...           NaN           NaN
# 4         0.030      0.168     -0.169  ...           NaN           NaN
# ...         ...        ...        ...  ...           ...           ...
# 9995        NaN        NaN        NaN  ...           NaN           NaN
# 9996      0.030      0.128      0.056  ...           NaN           NaN
# 9997      0.037      0.128      0.061  ...           NaN           NaN
# 9998        NaN        NaN        NaN  ...           NaN           NaN
# 9999      0.000      0.008      0.020  ...           NaN           NaN
#
#       L3_S50_F4249  L3_S50_F4251  L3_S50_F4253  L3_S51_F4256  L3_S51_F4258  \
# 0              NaN           NaN           NaN           NaN           NaN
# 1              NaN           NaN           NaN           NaN           NaN
# 2              NaN           NaN           NaN           NaN           NaN
# 3              NaN           NaN           NaN           NaN           NaN
# 4              NaN           NaN           NaN           NaN           NaN
# ...            ...           ...           ...           ...           ...
# 9995           NaN           NaN           NaN           NaN           NaN
# 9996           NaN           NaN           NaN           NaN           NaN
# 9997           NaN           NaN           NaN           NaN           NaN
# 9998           NaN           NaN           NaN           NaN           NaN
# 9999           NaN           NaN           NaN           0.0           0.0
#
#       L3_S51_F4260  L3_S51_F4262  Response
# 0              NaN           NaN         0
# 1              NaN           NaN         0
# 2              NaN           NaN         0
# 3              NaN           NaN         0
# 4              NaN           NaN         0
# ...            ...           ...       ...
# 9995           NaN           NaN         0
# 9996           NaN           NaN         0
# 9997           NaN           NaN         0
# 9998           NaN           NaN         0
# 9999           0.0           0.0         0
#
# [10000 rows x 970 columns]

# %%
category
# Out:
#          Id L0_S1_F25 L0_S1_F27 L0_S1_F29 L0_S1_F31 L0_S2_F33 L0_S2_F35  \
# 0         4       NaN       NaN       NaN       NaN       NaN       NaN
# 1         6       NaN       NaN       NaN       NaN       NaN       NaN
# 2         7       NaN       NaN       NaN       NaN       NaN       NaN
# 3         9       NaN       NaN       NaN       NaN       NaN       NaN
# 4        11       NaN       NaN       NaN       NaN       NaN       NaN
# ...     ...       ...       ...       ...       ...       ...       ...
# 9995  19912       NaN       NaN       NaN       NaN       NaN       NaN
# 9996  19915       NaN       NaN       NaN       NaN       NaN       NaN
# 9997  19917       NaN       NaN       NaN       NaN       NaN       NaN
# 9998  19921       NaN       NaN       NaN       NaN       NaN       NaN
# 9999  19923       NaN       NaN       NaN       NaN       NaN       NaN
#
#      L0_S2_F37 L0_S2_F39 L0_S2_F41  ... L3_S49_F4225 L3_S49_F4227  \
# 0          NaN       NaN       NaN  ...          NaN          NaN
# 1          NaN       NaN       NaN  ...          NaN          NaN
# 2          NaN       NaN       NaN  ...          NaN          NaN
# 3          NaN       NaN       NaN  ...          NaN          NaN
# 4          NaN       NaN       NaN  ...          NaN          NaN
# ...        ...       ...       ...  ...          ...          ...
# 9995       NaN       NaN       NaN  ...          NaN          NaN
# 9996       NaN       NaN       NaN  ...          NaN          NaN
# 9997       NaN       NaN       NaN  ...          NaN          NaN
# 9998       NaN       NaN       NaN  ...          NaN          NaN
# 9999       NaN       NaN       NaN  ...          NaN          NaN
#
#      L3_S49_F4229 L3_S49_F4230 L3_S49_F4232 L3_S49_F4234 L3_S49_F4235  \
# 0             NaN          NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...          ...
# 9995          NaN          NaN          NaN          NaN          NaN
# 9996          NaN          NaN          NaN          NaN          NaN
# 9997          NaN          NaN          NaN          NaN          NaN
# 9998          NaN          NaN          NaN          NaN          NaN
# 9999          NaN          NaN          NaN          NaN          NaN
#
#      L3_S49_F4237 L3_S49_F4239 L3_S49_F4240
# 0             NaN          NaN          NaN
# 1             NaN          NaN          NaN
# 2             NaN          NaN          NaN
# 3             NaN          NaN          NaN
# 4             NaN          NaN          NaN
# ...           ...          ...          ...
# 9995          NaN          NaN          NaN
# 9996          NaN          NaN          NaN
# 9997          NaN          NaN          NaN
# 9998          NaN          NaN          NaN
# 9999          NaN          NaN          NaN
#
# [10000 rows x 2141 columns]

# %% [markdown]
# # FEATURE ENGINEERING

# %%
chunks = pd.read_csv("/Users/maguoyi/Downloads/bosch-production-line-performance/train_numeric.csv.zip",chunksize=50000)

# %% [markdown]
# ### 1.The list of numeric and categorical features are selected based on the other XGBOOST classifier check the [numeric classifier notebook]() and [category classifier notebook]().

# %%
# 找出非空最多的numerical columns
# length = numeric.drop('Id', axis=1).count()
# numeric_cols = length.reset_index().sort_values(by=0, ascending=False)
# stations = sorted(numeric_cols['index'].str.split('_',expand=True)[1].unique().tolist())
# numeric_cols['station'] = numeric_cols['index'].str.split('_',expand=True)[1]
# numeric_cols = numeric_cols.drop_duplicates('station', keep='first')['index'].tolist()

# %%
num_feats = ['Id',
       'L3_S30_F3514', 'L0_S9_F200', 'L3_S29_F3430', 'L0_S11_F314',
       'L0_S0_F18', 'L3_S35_F3896', 'L0_S12_F350', 'L3_S36_F3918',
       'L0_S0_F20', 'L3_S30_F3684', 'L1_S24_F1632', 'L0_S2_F48',
       'L3_S29_F3345', 'L0_S18_F449', 'L0_S21_F497', 'L3_S29_F3433',
       'L3_S30_F3764', 'L0_S1_F24', 'L3_S30_F3554', 'L0_S11_F322',
       'L3_S30_F3564', 'L3_S29_F3327', 'L0_S2_F36', 'L0_S9_F180',
       'L3_S33_F3855', 'L0_S0_F4', 'L0_S21_F477', 'L0_S5_F114',
       'L0_S6_F122', 'L1_S24_F1122', 'L0_S9_F165', 'L0_S18_F439',
       'L1_S24_F1490', 'L0_S6_F132', 'L3_S29_F3379', 'L3_S29_F3336',
       'L0_S3_F80', 'L3_S30_F3749', 'L1_S24_F1763', 'L0_S10_F219',
 'Response']

# %%
cate_feats = ['Id', 'L3_S32_F3854', 'L1_S24_F1675', 'L2_S27_F3131', 'L1_S24_F1584',
       'L3_S29_F3317', 'L1_S24_F1510', 'L1_S24_F1525', 'L1_S24_F1530',
       'L1_S25_F2099', 'L2_S28_F3224', 'L1_S25_F1903', 'L2_S28_F3285',
       'L3_S29_F3475', 'L1_S25_F1852', 'L3_S47_F4141', 'L2_S26_F3038',
       'L1_S25_F2141', 'L2_S26_F3099', 'L2_S27_F3192', 'L1_S25_F2779',
       'L1_S25_F1981', 'L1_S24_F1114', 'L2_S26_F3042', 'L1_S25_F2948',
       'L2_S26_F3045', 'L2_S26_F3049', 'L2_S26_F3053', 'L1_S25_F3013',
       'L1_S25_F2983', 'L1_S25_F2993', 'L1_S25_F2988', 'L1_S25_F2938',
       'L1_S25_F2978', 'L1_S25_F2973', 'L1_S25_F2968']

# %% [markdown]
# ### 2.date data prepare

# %%
length = date.drop('Id', axis=1).count()
date_cols = length.reset_index().sort_values(by=0, ascending=False)
stations = sorted(date_cols['index'].str.split('_',expand=True)[1].unique().tolist())
date_cols['station'] = date_cols['index'].str.split('_',expand=True)[1]
date_cols = date_cols.drop_duplicates('station', keep='first')['index'].tolist()

# %%
data = None
for chunk in pd.read_csv('../bosch/input/train_date.csv.zip',usecols=['Id'] + date_cols,chunksize=50000,low_memory=False):

    chunk.columns = ['Id'] + stations
    chunk['start_station'] = -1
    chunk['end_station'] = -1
    
    for s in stations:
        chunk[s] = 1 * (chunk[s] >= 0)
        id_not_null = chunk[chunk[s] == 1].Id
        chunk.loc[(chunk['start_station']== -1) & (chunk.Id.isin(id_not_null)),'start_station'] = int(s[1:])
        chunk.loc[chunk.Id.isin(id_not_null),'end_station'] = int(s[1:])   
    data = pd.concat([data, chunk])

# %%
for chunk in pd.read_csv('../bosch/input/test_date.csv.zip',usecols=['Id'] + date_cols,chunksize=50000,low_memory=False):
    
    chunk.columns = ['Id'] + stations
    chunk['start_station'] = -1
    chunk['end_station'] = -1
    for s in stations:
        chunk[s] = 1 * (chunk[s] >= 0)
        id_not_null = chunk[chunk[s] == 1].Id
        chunk.loc[(chunk['start_station']== -1) & (chunk.Id.isin(id_not_null)),'start_station'] = int(s[1:])
        chunk.loc[chunk.Id.isin(id_not_null),'end_station'] = int(s[1:])   
    data = pd.concat([data, chunk])
del chunk
gc.collect()
# Out:
# 0

# %%
data = data[['Id','start_station','end_station']]
usefuldatefeatures = ['Id']+date_cols

# %%
minmaxfeatures = None
for chunk in pd.read_csv('../bosch/input/train_date.csv.zip',usecols=usefuldatefeatures,chunksize=50000,low_memory=False):
    features = chunk.columns.values.tolist()
    features.remove('Id')
    df_mindate_chunk = chunk[['Id']].copy()
    df_mindate_chunk['mindate'] = chunk[features].min(axis=1).values
    df_mindate_chunk['maxdate'] = chunk[features].max(axis=1).values
    df_mindate_chunk['min_time_station'] =  chunk[features].idxmin(axis = 1).apply(lambda s: int(s.split('_')[1][1:]) if s is not np.nan else -1)
    df_mindate_chunk['max_time_station'] =  chunk[features].idxmax(axis = 1).apply(lambda s: int(s.split('_')[1][1:]) if s is not np.nan else -1)
    minmaxfeatures = pd.concat([minmaxfeatures, df_mindate_chunk])

del chunk
gc.collect()
# Out:
# 0

# %%
for chunk in pd.read_csv('../bosch/input/test_date.csv.zip',usecols=usefuldatefeatures,chunksize=50000,low_memory=False):
    features = chunk.columns.values.tolist()
    features.remove('Id')
    df_mindate_chunk = chunk[['Id']].copy()
    df_mindate_chunk['mindate'] = chunk[features].min(axis=1).values
    df_mindate_chunk['maxdate'] = chunk[features].max(axis=1).values
    df_mindate_chunk['min_time_station'] =  chunk[features].idxmin(axis = 1).apply(lambda s: int(s.split('_')[1][1:]) if s is not np.nan else -1)
    df_mindate_chunk['max_time_station'] =  chunk[features].idxmax(axis = 1).apply(lambda s: int(s.split('_')[1][1:]) if s is not np.nan else -1)
    minmaxfeatures = pd.concat([minmaxfeatures, df_mindate_chunk])

del chunk
gc.collect()
# Out:
# 0

# %%
minmaxfeatures.sort_values(by=['mindate', 'Id'], inplace=True)
minmaxfeatures['min_Id_rev'] = -minmaxfeatures.Id.diff().shift(-1)
minmaxfeatures['min_Id'] = minmaxfeatures.Id.diff()

# %% [markdown]
# ### 3.merge the data

# %%
cols = [['Id']+date_cols,num_feats, cate_feats]

# %%
traindata = None

# %%
testdata = None

# %%
trainfiles = ['train_date.csv.zip','train_numeric.csv.zip','train_categorical_to_num.csv.zip']
testfiles = ['test_date.csv.zip','test_numeric.csv.zip','test_categorical_to_num.csv.zip']

# %%
for i,f in enumerate(trainfiles):
    
    subset = None
    
    for chunk in pd.read_csv('../bosch/input/' + f,usecols=cols[i],chunksize=100000,low_memory=False):
        subset = pd.concat([subset, chunk])
    
    if traindata is None:
        traindata = subset.copy()
    else:
        traindata = pd.merge(traindata, subset.copy(), on="Id")
        
del subset,chunk
gc.collect()
del cols[1][-1]

# %%
for i, f in enumerate(testfiles):
    subset = None
    
    for chunk in pd.read_csv('../bosch/input/' + f,usecols=cols[i],chunksize=100000,low_memory=False):
        subset = pd.concat([subset, chunk])
        
    if testdata is None:
        testdata = subset.copy()
    else:
        testdata = pd.merge(testdata, subset.copy(), on="Id")
    
del subset,chunk
gc.collect()
del cols[1][-1]

# %%
traindata = traindata.merge(minmaxfeatures, on='Id')
traindata = traindata.merge(data, on='Id')
testdata = testdata.merge(minmaxfeatures, on='Id')
testdata = testdata.merge(data, on='Id')

# %%
del minmaxfeatures,data
gc.collect()
# Out:
# 0

# %%
traindata
# Out:
#               Id  L0_S0_D3  L0_S1_D30  L0_S2_D54  L0_S3_D70  L0_S4_D106  \
# 0              4     82.24      82.24      82.24        NaN       82.26
# 1              6       NaN        NaN        NaN        NaN         NaN
# 2              7   1618.70    1618.70    1618.70        NaN         NaN
# 3              9   1149.20    1149.20    1149.21        NaN     1149.22
# 4             11    602.64     602.64        NaN     602.64      602.66
# ...          ...       ...        ...        ...        ...         ...
# 1183742  2367490   1239.90    1239.90    1239.91        NaN     1239.93
# 1183743  2367491       NaN        NaN        NaN        NaN         NaN
# 1183744  2367492   1482.18    1482.18        NaN    1482.19         NaN
# 1183745  2367493    608.83     608.83        NaN     608.83      608.85
# 1183746  2367495    937.61     937.61     937.61        NaN      937.64
#
#          L0_S5_D115  L0_S6_D120  L0_S7_D143  L0_S8_D145  ...  L3_S32_F3854  \
# 0               NaN         NaN       82.26       82.27  ...           NaN
# 1               NaN         NaN         NaN         NaN  ...           NaN
# 2           1618.72     1618.72         NaN     1618.73  ...           NaN
# 3               NaN         NaN     1149.22     1149.22  ...           NaN
# 4               NaN         NaN      602.67      602.67  ...           NaN
# ...             ...         ...         ...         ...  ...           ...
# 1183742         NaN     1239.93         NaN     1239.94  ...           NaN
# 1183743         NaN         NaN         NaN         NaN  ...           NaN
# 1183744     1482.20     1482.21         NaN     1482.21  ...           NaN
# 1183745         NaN         NaN      608.85      608.85  ...           NaN
# 1183746         NaN         NaN      937.64      937.65  ...           NaN
#
#          L3_S47_F4141  mindate  maxdate  min_time_station  max_time_station  \
# 0                 NaN    82.24    87.29                 0                35
# 1                 NaN  1313.12  1315.75                12                33
# 2                 NaN  1618.70  1624.42                 0                33
# 3                 NaN  1149.20  1154.16                 0                36
# 4                 NaN   602.64   606.02                 0                36
# ...               ...      ...      ...               ...               ...
# 1183742           NaN  1239.90  1244.04                 0                33
# 1183743           NaN   624.22   626.66                12                36
# 1183744           NaN  1482.18  1490.61                 0                34
# 1183745           NaN   608.83   610.75                 0                33
# 1183746           NaN   937.61   942.33                 0                37
#
#          min_Id_rev     min_Id  start_station  end_station
# 0         -224451.0 -2314450.0              0           42
# 1          -67530.0 -2284042.0              2           42
# 2          -26876.0 -2313512.0              0           42
# 3           -3564.0 -2196581.0              0           42
# 4              -1.0 -2226678.0              0           42
# ...             ...        ...            ...          ...
# 1183742   2365689.0   925004.0              0           42
# 1183743   1572356.0    71839.0              2           42
# 1183744   2358793.0    53955.0              0           42
# 1183745   2357190.0     8988.0              0           42
# 1183746   2366095.0     4111.0              0           42
#
# [1183747 rows x 137 columns]

# %%
testdata
# Out:
#               Id  L0_S0_D3  L0_S1_D30  L0_S2_D54  L0_S3_D70  L0_S4_D106  \
# 0              1       NaN        NaN        NaN        NaN         NaN
# 1              2       NaN        NaN        NaN        NaN         NaN
# 2              3       NaN        NaN        NaN        NaN         NaN
# 3              5    255.45     255.45     255.46        NaN      255.48
# 4              8       NaN        NaN        NaN        NaN         NaN
# ...          ...       ...        ...        ...        ...         ...
# 1183743  2367483    653.85     653.85     653.85        NaN      653.86
# 1183744  2367485    907.34     907.34        NaN     907.34         NaN
# 1183745  2367486    185.92     185.92     185.92        NaN      185.96
# 1183746  2367489    570.85     570.85     570.86        NaN         NaN
# 1183747  2367494   1412.80    1412.80        NaN    1412.81         NaN
#
#          L0_S5_D115  L0_S6_D120  L0_S7_D143  L0_S8_D145  ...  L3_S32_F3854  \
# 0               NaN         NaN         NaN         NaN  ...           NaN
# 1               NaN         NaN         NaN         NaN  ...           NaN
# 2               NaN         NaN         NaN         NaN  ...           NaN
# 3               NaN         NaN      255.48      255.48  ...           NaN
# 4               NaN         NaN         NaN         NaN  ...           NaN
# ...             ...         ...         ...         ...  ...           ...
# 1183743         NaN         NaN      653.87      653.87  ...           NaN
# 1183744      907.37         NaN      907.37      907.37  ...           NaN
# 1183745         NaN      185.96         NaN      185.96  ...           NaN
# 1183746      570.88         NaN      570.89      570.89  ...           NaN
# 1183747     1412.82     1412.82         NaN     1412.83  ...           NaN
#
#          L3_S47_F4141  mindate  maxdate  min_time_station  max_time_station  \
# 0                 NaN   792.77   800.70                24                34
# 1                 NaN  1045.96  1060.07                27                36
# 2                 NaN   671.95   711.08                24                34
# 3                 NaN   255.45   256.28                 0                36
# 4                 NaN   743.40   770.28                24                33
# ...               ...      ...      ...               ...               ...
# 1183743           NaN   653.85   655.45                 0                35
# 1183744           NaN   907.34   911.29                 0                34
# 1183745           NaN   185.92   186.32                 0                35
# 1183746           NaN   570.85   572.67                 0                35
# 1183747           NaN  1412.80  1413.18                 0                33
#
#          min_Id_rev     min_Id  start_station  end_station
# 0           -3232.0 -2326858.0             30           42
# 1          -62612.0 -2366837.0             33           42
# 2          -16069.0 -2315057.0             30           42
# 3          -33948.0 -2364005.0              0           42
# 4           -4312.0 -1898699.0             30           42
# ...             ...        ...            ...          ...
# 1183743   2042322.0     7590.0              0           42
# 1183744   2318983.0     3483.0              0           42
# 1183745   2316034.0     4732.0              0           42
# 1183746   2351203.0    10503.0              0           42
# 1183747   2362123.0    35783.0              0           42
#
# [1183748 rows x 136 columns]

# %%
traindata.fillna(value=0,inplace=True)
testdata.fillna(value=0,inplace=True)

# %%
np.set_printoptions(suppress=True)

# %%
import gc

# %%
total = traindata[traindata['Response']==0].sample(frac=1).head(400000)
total = pd.concat([total,traindata[traindata['Response']==1]]).sample(frac=1)

# %%
from sklearn.model_selection import train_test_split

# %%
X,y = total.drop(['Response','Id'],axis=1),total['Response']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42,stratify=y)

# %% [markdown]
# # MODELLING

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

# %%
def get_classifiers():
	classifiers = list()
	classifiers.append(AdaBoostClassifier())
	classifiers.append(BaggingClassifier())
	classifiers.append(RandomForestClassifier())
	classifiers.append(ExtraTreesClassifier())
	classifiers.append(GradientBoostingClassifier())
	classifiers.append(LogisticRegression())
	return classifiers 

# loading the models 
classifiers = get_classifiers()

#fit the models according to training dataset  
#create loaded_models folder in google collab 
def fit_base_classifiers(X_train , y_train , classifiers):
	for classifier in classifiers:
		classifier.fit(X_train, y_train)

# %%
fit_base_classifiers(X_train , y_train , classifiers) 
from sklearn.metrics import matthews_corrcoef

# storing the predicted values by each model in given array and printing the rmse ( error)
ypredicted = []
def evaluate_classifiers(X_test, y_test, classifiers):
    for classifier in classifiers:
        yhat = classifier.predict(X_test) 
        print(classifier)
        ypredicted.append(yhat)
        mcc = matthews_corrcoef(y_test, yhat)
        print('%s: MCC %.3f' % (classifier.__class__.__name__, mcc))

#predicted values on our testdataset testX 
evaluate_classifiers(X_test , y_test , classifiers)
################################
# Out:
# AdaBoostClassifier()
# AdaBoostClassifier: MCC 0.355
# BaggingClassifier()
# BaggingClassifier: MCC 0.378
# RandomForestClassifier()
# RandomForestClassifier: MCC 0.407
# ExtraTreesClassifier()
# ExtraTreesClassifier: MCC 0.251
# GradientBoostingClassifier()
# GradientBoostingClassifier: MCC 0.362
# LogisticRegression()
# LogisticRegression: MCC 0.002

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
test = model.predict(testdata.drop(['Id'],axis=1))
testdata['Response'] = test
testdata[['Id','Response']].to_csv("submission.csv",index=False)
